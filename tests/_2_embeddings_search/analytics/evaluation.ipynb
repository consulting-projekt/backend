# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

import json
from utils import load_promptfoo_results, extract_metrics

# %%
res = load_promptfoo_results("results_std.json")
metrics_std = extract_metrics(res)

# %%
metrics_std
# Out:
# {'score': 9.5,
#  'testPassCount': 7,
#  'testFailCount': 18,
#  'testErrorCount': 0,
#  'assertPassCount': 7,
#  'assertFailCount': 18,
#  'totalLatencyMs': 258,
#  'tokenUsage': {'total': 0,
#   'prompt': 0,
#   'completion': 0,
#   'cached': 0,
#   'numRequests': 25,
#   'completionDetails': {'reasoning': 0,
#    'acceptedPrediction': 0,
#    'rejectedPrediction': 0},
#   'assertions': {'total': 0, 'prompt': 0, 'completion': 0, 'cached': 0}},
#  'namedScores': {},
#  'namedScoresCount': {},
#  'cost': 0}
