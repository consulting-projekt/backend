# %%
import neo4j
import pandas as pd

# %%
NEO4J_URI = "bolt://localhost:7689"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "busticket123"

driver = neo4j.GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

# %%
query = """
MATCH (n)
WHERE n:Station
RETURN 
    n.name AS name,
    n.location AS location,
    labels(n) AS node_type
"""

# %%
# Execute query and process results
with driver.session() as session:
    result = session.run(query)
    records = result.data()

# %%
# Convert to DataFrame
df = pd.DataFrame(records)

# %%
df
# Out:
#                               name               location  node_type
# 0              Heinrich-Hertz-Turm  (9.976376, 53.564601)  [Station]
# 1                U S Jungfernstieg  (9.992846, 53.553135)  [Station]
# 2     Universität/Staatsbibliothek  (9.984176, 53.564429)  [Station]
# 3                      Bf. Dammtor    (9.9903, 53.561045)  [Station]
# 4                         Fontenay  (9.994508, 53.564811)  [Station]
# ...                            ...                    ...        ...
# 8823               U Stephansplatz   (9.98901, 53.558154)  [Station]
# 8824                Sievekingplatz   (9.97755, 53.555957)  [Station]
# 8825          Museum am Rothenbaum  (9.988378, 53.567962)  [Station]
# 8826                  U Feldstraße   (9.969041, 53.55732)  [Station]
# 8827             Neuer Pferdemarkt  (9.963346, 53.558408)  [Station]
#
# [8828 rows x 3 columns]

# %%
# Generate filename with current timestamp
filename = f"station_data.csv"

# Save to CSV
df.to_csv(filename, index=False)

print(f"Data successfully exported to {filename}")

# Close the driver connection
driver.close()
# Out:
# Data successfully exported to station_data.csv
